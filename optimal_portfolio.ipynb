# %% [markdown]
# # 1.Prepare for dataset

# %% [markdown]
# ## 1.1download data from yahoo
# seperate the dataframes into several dataframes by closing price and volume

# %%
from pandas_datareader import data as pdr
import fix_yahoo_finance as yf
yf.pdr_override()

tickers_list = pd.read_csv('Yahoo_Ticker_Symbols.csv')

tickers_list.drop(columns=['Category Name'],axis=1,inplace=True)

tickers = list(tickers_list.Ticker)

len(tickers)

start_time = datetime.strptime('Jan 1 2000 ', '%b %d %Y ')
start_time

for i in range(0,21):
    start = i * 5000
    end = (i+1)*5000
    Total_data_1 = pdr.get_data_yahoo(tickers=tickers[start:end],start=start_time,end=datetime.now())
    closing_price = Total_data_1['Close']
    volume = Total_data_1['Volume']
    closing_price.to_csv('closing_part'+str(i)+'.csv')
    volume.to_csv('volume_part'+str(i)+'.csv')
    print('finished '+str(i)+'loop')

# %%
tickers_list = pd.read_csv('Yahoo_Ticker_Symbols.csv')
len(tickers_list)
# Out:
# 106328

# %% [markdown]
# ## 1.2 input data as dataframe through pandas from csv files
# transfer dataframe index from str to datetime to filter data on Saturday and then output as pickle file to easy input in the future analysis.

# %%
import glob
import pandas as pd 
path ='data' # use your path
allFiles = glob.glob(path + "/*.csv")

clo_price_data = []
vol_data = []
for file in allFiles:
    if file.startswith('data/closing'):
        data = pd.read_csv(file).set_index('Date')
        clo_price_data.append(data)
        print('Successful import closing price file '+file)
#     else:
#         data = pd.read_csv(file).set_index('Date')
#         vol_data.append(data)
#         print('Successful import volume  file'+file)
data_clo = pd.concat(clo_price_data, axis = 1, ignore_index = False,sort=False)
data_clo.index = pd.to_datetime(data_clo.index)
# data_clo.sort_index(inplace=True)
# data_clo = data_clo.iloc[2:-1,:]

clo_price_data  = []
data_clo.index = pd.to_datetime(data_clo.index)

data_clo[data_clo.index.weekday!=6].to_pickle('data/closing_price.pkl')

# %% [markdown]
# ## 1.3 data preprocessing

# %%
import pandas as pd
from datetime import datetime
from datetime import timedelta
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.stats as stats
from sklearn.covariance import LedoitWolf
import scipy.optimize as sco
import warnings
warnings.filterwarnings("ignore")

# %%
clo_data = pd.read_pickle('closing_price.pkl')

clo_data.index = pd.to_datetime(clo_data.index)
clo_data.sort_index(inplace=True)  ## transfet index from str to datetime and then sort by datetime

numNAs = (clo_data.isna().sum()/len(clo_data)).copy()

# %%
fig,ax = plt.subplots(figsize=(8,5))
numNAs.hist()
ax.set_xlabel('Nan values percentage')
ax.set_ylabel('Frequency')
fig.savefig('figure/Nan_value_distribution.jpg')

# %%
fig, ax = plt.subplots(figsize=(8,5))
clearn_numNAs = clo_data.isna().sum(axis=1)
plt.plot(clearn_numNAs)
ax.set_xlabel('Year')
ax.set_ylabel('Num of Nan values')
fig.savefig('figure/Nan_value_distribution2.jpg')

# %% [markdown]
# ### select stocks which have at most 3% data missing

# %%
stock_list =(numNAs<=0.025).copy()
stock_list = stock_list[stock_list==True]
cleaned_clo_data = clo_data[list(stock_list.index)]
# we select stock with nan value percentage less then 3%
# large threshold will lead to a not precision result and too low may cause too less stocks

cleaned_clo_data
# Out:
#                    CIN.L  CIR.MI   CKN.L     CLE.MI   CLI.L     CRI.PA  \
# 2000-01-31   4.860  441.710999  10.350000   4.0125    ...      2866.780029
# 2000-02-01   4.900  441.710999  10.500000   4.0500    ...      2778.090088
# 2000-02-02   5.040  441.710999  10.450000   4.0625    ...      2800.979980
# 2000-02-03   5.140  435.151001  10.700000   4.2625    ...      2878.229980
# 2000-02-04   5.090  433.838989  11.950000   4.1250    ...      2758.060059
# 2000-02-07   4.960  432.089996  12.450000   4.1250    ...      2838.169922
# 2000-02-08   5.260  424.217987  13.700000   4.1250    ...      3012.699951
# 2000-02-09   5.150  424.217987  16.299999   4.1250    ...      2586.399902
# 2000-02-10   5.450  424.217987  15.000000   4.1250    ...      2503.429932
# 2000-02-11   5.600  424.217987  16.900000   4.1250    ...      2491.979980
# ...            ...         ...        ...      ...    ...              ...
# 2018-12-03   0.800  981.000000   2.500000   9.7200    ...       221.300003
# 2018-12-04   0.798  770.000000   2.430000  10.2000    ...       216.800003
# 2018-12-05   0.772  745.000000   2.420000   9.9800    ...       222.000000
# 2018-12-06   0.756  700.000000   2.410000   9.9200    ...       212.000000
# 2018-12-07   0.760  734.000000   2.310000   9.9200    ...       210.000000
# 2018-12-10   0.790  727.000000   2.240000   9.9200    ...       203.600006
# 2018-12-11   0.790  720.000000   2.230000   9.9200    ...       203.000000
# 2018-12-12   0.778  739.000000   2.240000   9.8800    ...       208.500000
# 2018-12-13   0.778  737.000000   2.300000   9.8800    ...       210.899994
# 2018-12-14   0.778  745.000000   2.250000   9.7400    ...       211.600006
# 2018-12-17   0.778  745.000000   2.250000   9.6000    ...       208.199997
# 2018-12-18   0.734  749.000000   2.250000   9.5800    ...       209.300003
# 2018-12-19   0.768  769.000000   2.240000   9.2200    ...       209.899994
# 2018-12-20   0.766  761.000000   2.230000   9.1400    ...       207.699997
# 2018-12-21   0.758  820.000000   2.220000   9.1000    ...       208.699997
# 2018-12-22     NaN         NaN        NaN      NaN    ...              NaN
# 2018-12-24     NaN  817.500000   2.060000   9.0800    ...       206.000000
# 2018-12-25     NaN         NaN        NaN      NaN    ...              NaN
# 2018-12-26     NaN         NaN        NaN      NaN    ...              NaN
# 2018-12-27   0.762  846.000000   2.000000   9.0200    ...       206.100006
# 2018-12-28   0.752  900.000000   2.050000   9.0400    ...       214.100006
# 2018-12-31     NaN  935.000000   2.060000   9.1600    ...       216.699997
# 2019-01-01     NaN         NaN        NaN      NaN    ...              NaN
# 2019-01-02   0.738  930.000000   2.050000   9.1400    ...       216.600006
# 2019-01-03   0.750  869.000000   2.120000   9.1000    ...       213.100006
# 2019-01-04   0.742  851.000000   2.270000   9.1000    ...       221.199997
# 2019-01-07   0.740  770.000000   2.300000   9.1400    ...       224.000000
# 2019-01-08   0.750  833.500000   2.250000   9.2200    ...       225.800003
# 2019-01-09   0.750  882.000000   2.320000   9.3600    ...       220.899994
# 2019-01-10   0.798  886.000000   2.320000   9.2800    ...       224.100006
#
#              REC.BR      RMS.PA   SAB.MC    SAN.MC     SIP.BR    SIPH.PA  \
# 2000-02-11   69.942398  40.388302  35.619999
# ...                ...        ...        ...
# 2018-12-03  119.000000  31.049999  75.000000
# 2018-12-04  117.500000  30.799999  75.959999
# 2018-12-05  119.500000  30.350000  75.000000
# 2018-12-06  116.000000  30.350000  74.019997
# 2018-12-07  118.000000  30.299999  75.400002
# 2018-12-10  112.000000  29.400000  75.879997
# 2018-12-11  114.500000  29.950001  76.720001
# 2018-12-12  114.500000  30.400000  77.099998
# 2018-12-13  116.500000  30.150000  75.500000
# 2018-12-14  115.500000  30.299999  74.959999
# 2018-12-17  114.500000  29.549999  74.239998
# 2018-12-18  114.000000  29.100000  73.320000
# 2018-12-19  114.000000  29.400000  72.139999
# 2018-12-20  113.500000  28.950001  73.260002
# 2018-12-21  111.500000  28.500000  72.220001
# 2018-12-22         NaN        NaN        NaN
# 2018-12-24  112.000000  28.549999  71.739998
# 2018-12-25         NaN        NaN        NaN
# 2018-12-26         NaN        NaN        NaN
# 2018-12-27  111.500000  28.250000  70.760002
# 2018-12-28  111.500000  29.000000  71.480003
# 2018-12-31  110.500000  29.100000  71.300003
# 2019-01-01         NaN        NaN        NaN
# 2019-01-02  112.500000  29.750000  70.480003
# 2019-01-03  111.000000  29.350000  70.580002
# 2019-01-04  111.000000  29.950001  71.379997
# 2019-01-07  114.000000  30.150000  71.260002
# 2019-01-08  112.500000  30.100000  73.139999
# 2019-01-09  114.000000  30.200001  75.739998
# 2019-01-10  117.500000  30.350000  76.559998
#
# [4980 rows x 454 columns]

# %% [markdown]
# ### distribution of stocks on exchange

# %%
tickers_list = pd.read_csv('Yahoo_Ticker_Symbols.csv')

Exchange_list = tickers_list.Exchange.unique()

Ticker_df = tickers_list.set_index('Ticker')

Exchange_dict = {}
for name in cleaned_clo_data.columns:
    exchange = Ticker_df.loc[name].Exchange
    if exchange not in Exchange_dict.keys():
        Exchange_dict[exchange] = [name]
    else:
        Exchange_dict[exchange].append(name)

xdata = list(Exchange_dict.keys())
ydata = [len(Exchange_dict[key]) for key in xdata]

fig,ax = plt.subplots(figsize=(8,5))
plt.bar(xdata,ydata)
ax.set_xlabel('Exchange')
fig.savefig('figure/Exchange_distribution')

# %% [markdown]
# ### fill nan value by ffill method  and drop ticker with nan at the begining

# %%
price_data = cleaned_clo_data.fillna(method='ffill')
price_data = price_data.dropna(axis=1)

price_data
# Out:
#                    CIN.L  CIR.MI   CKN.L     CLE.MI   CLI.L     CRI.PA  \
# 2000-01-03   2384.379883   2.425    93.5  41.136902   13.55  18.600000
# 2000-01-04   2452.500000   2.335    93.5  39.568501   13.55  18.766701
# 2000-01-05   2222.399902   2.185    87.5  37.306000   13.45  19.000000
# 2000-01-06   2222.399902   2.150    87.5  33.835098   13.25  19.333300
# 2000-01-07   2222.399902   2.200    87.5  37.203201   13.25  19.366699
# 2000-01-10   2251.639893   2.200    87.5  39.979900   13.25  19.533300
# 2000-01-11   2462.229980   2.380    87.5  42.293900   13.25  19.333300
# 2018-12-13  490.500000  1.07850   4.07100
# 2018-12-14  485.799988  1.08350   4.05950
# 2018-12-17  476.799988  1.06850   4.02700
# 2018-12-18  474.100006  1.05200   3.99000
# 2018-12-19  477.299988  1.03700   4.04150
# 2018-12-20  473.299988  1.01250   3.97800
# 2018-12-21  475.399994  0.99780   3.93050
# 2018-12-22  475.399994  0.99780   3.93050
# 2018-12-24  463.500000  0.97240   3.89150
# 2018-12-25  463.500000  0.97240   3.89150
# 2018-12-26  463.500000  0.97240   3.89150
# 2018-12-27  469.299988  0.96100   3.86200
# 2018-12-28  476.799988  0.99240   3.94500
# 2018-12-31  484.799988  1.00050   3.97300
# 2019-01-01  484.799988  1.00050   3.97300
# 2019-01-02  477.600006  1.00100   3.97750
# 2019-01-03  464.000000  0.99760   4.00950
# 2019-01-04  477.799988  1.04400   4.15950
# 2019-01-07  472.200012  1.04750   4.18300
# 2019-01-08  479.899994  1.04850   4.21750
# 2019-01-09  491.200012  1.04700   4.19950
# 2019-01-10  489.899994  1.03100   4.27550
#
# [4980 rows x 412 columns]

# %% [markdown]
# ## 1.4 Compute price return and then plot one stock price return as example.

# %% [markdown]
# ### plot the returns for Credit Suiss since we will use Credit Suiss stock to do machine learning

# %%
credit = clo_data[['CS']]

credit = credit.fillna(method='ffill')

credit_log_return = np.log(credit).diff()
credit_log_return = credit_log_return.iloc[1:,:]

fig,ax = plt.subplots(figsize=(8,5))
plt.plot(credit_log_return) # plot the stock called 'CIR.MI'
ax.set_xlabel('date')
ax.set_ylabel('log returns')
fig.savefig('figure/log_returns_for_CS.jpg')

# %%
log_return = np.log(price_data).diff()
log_return.index.name = 'date'

# %%
log_return
# Out:
#                CIN.L    CIR.MI     CKN.L    CLE.MI     CLI.L    CRI.PA  \
# date
# 2000-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2000-01-04  0.028169 -0.037820  0.000000 -0.038872  0.000000  0.008922
# 2000-01-05 -0.098520 -0.066396 -0.066323 -0.058879 -0.007407  0.012355
# 2000-01-06  0.000000 -0.016148  0.000000 -0.097656 -0.014982  0.017390
# 2000-01-07  0.000000  0.022990  0.000000  0.094896  0.000000  0.001726
# 2000-01-10  0.013071  0.000000  0.000000  0.071982  0.000000  0.008566
# 2000-01-11  0.089409  0.078643  0.000000  0.056266  0.000000 -0.010292
# 2000-01-12  0.040326  0.080689  0.000000 -0.015315  0.000000  0.010292
# 2000-01-13  0.154696  0.041752  0.000000 -0.021212  0.000000 -0.025931
# 2000-01-14  0.467556  0.009251  0.000000 -0.000630  0.011257  0.012188
# 2000-01-17  0.483937  0.023659  0.000000  0.023076  0.000000  0.035688
# 2000-01-18 -0.085298  0.017826  0.000000 -0.045404  0.000000 -0.003346
# 2000-01-19 -0.116071 -0.017826  0.000000  0.007712  0.000000 -0.008412
# 2000-01-20 -0.031253 -0.019982  0.000000 -0.001281  0.000000  0.013425
# 2000-01-21  0.038915 -0.001837  0.087487 -0.012906  0.000000 -0.011734
# 2000-01-24 -0.260076  0.010969 -0.010526 -0.012412  0.000000 -0.001691
# 2019-01-01  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2019-01-02  0.000000 -0.013001  0.058765  0.030098  0.023420 -0.004773
# 2019-01-03  0.000000  0.044784  0.053153  0.002692 -0.032944 -0.014458
# 2019-01-04  0.000000 -0.008377  0.004695  0.021277  0.039865  0.012662
# 2019-01-07  0.000000  0.000000  0.052464 -0.026668  0.004587  0.039935
# 2019-01-08  0.000000 -0.011634  0.039221  0.002699 -0.004587  0.024454
# 2019-01-09  0.000000  0.001063 -0.015070  0.013387 -0.004608  0.043425
# 2019-01-10  0.000000  0.003183  0.036213  0.015831  0.006905  0.012828
#
#               CSP.MI    CSRT.L   CTAC.AS   CTRG.PA    ...       DBK.DE  \
# date                                                  ...
# 2000-01-03       NaN       NaN       NaN       NaN    ...          NaN
# 2000-01-04 -0.038350  0.000000 -0.046281 -0.012732    ...    -0.051582
# 2000-01-05 -0.025001  0.008637 -0.032088 -0.035728    ...    -0.013036
# 2000-01-06 -0.008475  0.056010  0.000000  0.035728    ...     0.049700
# 2000-01-07  0.010582  0.000000  0.032088 -0.035151    ...     0.029853
# 2000-01-10  0.006296  0.000000  0.010471  0.035151    ...    -0.026103
# 2000-01-11 -0.010515 -0.050010 -0.037140 -0.025389    ...     0.003497
# 2000-01-12 -0.002116  0.000000 -0.010870  0.000000    ...    -0.030546
# 2000-01-13 -0.021414 -0.011173  0.005450 -0.033705    ...     0.035946
# 2000-01-14  0.000000 -0.014803  0.005420  0.000591    ...     0.006561
# 2000-01-17  0.000000 -0.012357  0.005391 -0.042842    ...     0.026171
# 2000-01-18 -0.010882 -0.005343 -0.032790  0.058083    ...    -0.014937
# 2000-01-19  0.004367 -0.001786  0.011050  0.008111    ...    -0.002944
# 2000-01-20  0.002176 -0.007182  0.037740  0.046231    ...    -0.007695
# 2000-01-21  0.000000 -0.018183  0.183203 -0.000551    ...    -0.019682
# 2000-01-24  0.012959 -0.001835  0.026088 -0.050307    ...    -0.023421
# 2000-01-25  0.004283 -0.007381 -0.030503 -0.015187    ...    -0.027674
# 2000-01-26  0.000000 -0.009304 -0.013363 -0.058787    ...     0.013429
# 2000-01-27 -0.025975  0.000000  0.004474  0.000000    ...    -0.003278
# 2000-01-28 -0.013245 -0.038099 -0.045670  0.002494    ...    -0.008367
# 2000-01-31  0.076961 -0.019609 -0.033257 -0.000623    ...    -0.019803
# 2000-02-01  0.008197  0.000000  0.014389  0.009302    ...     0.024375
# 2000-02-02  0.028171  0.000000 -0.004773  0.003082    ...     0.043283
# 2000-02-03  0.019647 -0.014963  0.023642  0.048057    ...     0.007738
# 2000-02-04 -0.009775 -0.003020  0.110488 -0.032790    ...    -0.001567
# 2000-02-07 -0.025872 -0.004040  0.040989  0.000000    ...    -0.008479
# 2000-02-08  0.058725 -0.018386  0.095675  0.000000    ...     0.007272
# 2000-02-09 -0.021134  0.000000  0.173769  0.000000    ...     0.006021
# 2000-02-10  0.056619  0.000000 -0.083115  0.000000    ...     0.025484
# 2000-02-11  0.027151  0.000000  0.119263  0.000000    ...     0.003504
# ...              ...       ...       ...       ...    ...          ...
# 2018-12-03  0.012579 -0.016178  0.016129 -0.048202    ...     0.031617
# 2018-12-04 -0.002503 -0.242182 -0.028399  0.048202    ...    -0.031989
# 2018-12-05 -0.033124 -0.033006 -0.004124 -0.021805    ...    -0.000621
0.000000  0.000000  0.000000
# 2018-12-26  0.000000  0.000000  0.000000
# 2018-12-27  0.012436 -0.011793 -0.007610
# 2018-12-28  0.015855  0.032152  0.021264
# 2018-12-31  0.016639  0.008129  0.007073
# 2019-01-01  0.000000  0.000000  0.000000
# 2019-01-02 -0.014963  0.000500  0.001132
# 2019-01-03 -0.028889 -0.003402  0.008013
# 2019-01-04  0.029308  0.045462  0.036728
# 2019-01-07 -0.011790  0.003347  0.005634
# 2019-01-08  0.016175  0.000954  0.008214
# 2019-01-09  0.023274 -0.001432 -0.004277
# 2019-01-10 -0.002650 -0.015400  0.017936
#
# [4980 rows x 412 columns]

# %% [markdown]
#  ### The autocorrelation function of returns
#  compute the autocorrelation of 'CIR.MI' ticker

# %%
data_acc = np.array(list(log_return.iloc[1:,1]))
fig,ax = plt.subplots(figsize=(8,5))
plt.acorr(data_acc, maxlags=9)
#plt.title('Autocorrelation of CIR.MI stock log returns')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
# Display the autocorrelation plot
plt.show()
fig.savefig('figure/autocorrelation')

# %% [markdown]
# ### plot cdf

# %%
data_acc = abs(np.array(log_return.iloc[1:,1]))

xdata = np.arange(0,0.101,0.001)

# %%
def cdf(data):
    CDF = []
    length = xdata.size
    for i in range(length):
        fre = (data<xdata[i]).sum()
        CDF.append(1-fre/len(data))
    return CDF
fig,ax = plt.subplots(figsize=(8,5))
plt.plot(xdata,cdf(data_acc))
ax.set_xlabel('|x|')
ax.set_ylabel('1-P(X<x)')
fig.savefig('figure/cdf_fig')

# %% [markdown]
# # Markowitz  mean-variance portfolio
# we separate our data into two parts in order to do out-sample prediction.

# %%
def random_portfolio(returns_mean,returns_cov):
    ''' 
    Returns the mean and standard deviation of returns for a random portfolio
    '''

    p = returns_mean
    w = np.random.random(num_stocks)
    w /=np.sum(w)
    C = returns_cov
    mu = np.sum(p*w)
    sigma = np.sqrt(np.dot(w.T,np.dot(C,w)))
    
    # This recursion reduces outliers to keep plots pretty
    if sigma > 1:
        return random_portfolio(returns)
    return mu, sigma

def statistics(weights):        

    weights = np.array(weights)
    pret = np.sum(returns_mean * weights) # total returns 
    pvol = np.sqrt(np.dot(weights.T, np.dot(returns_cov, weights))) # std 
    return np.array([pret, pvol, pret / pvol])

# %%
def corr2cov(corr,std):
    std_diag = np.diag(std)
    cov = np.dot(np.dot(std_diag,corr),std_diag)
    return cov

def compute_cov_metrix(returns,method,threshold=0):
    if method == 'normal':
        corr = np.corrcoef(returns.T)
        std = returns.std()
        return corr2cov(corr,std)
    elif method == 'Shrinkage':
        
        return 0
    elif method =='clipping':
        corr = np.corrcoef(returns.T)
        std = returns.std() 
        u,v = np.linalg.eig(corr)
        N =len(u)
        C_clean = np.zeros((N,N))
        v_m = np.matrix(v.T)
        lambda_M = max(u)
        for i in range(N):
            if u[i] > threshold and u[i] < lambda_M:
                C_clean = C_clean + u[i] * np.dot(v_m[i,].T,v_m[i,])
        return np.array(C_clean)

# %% [markdown]
# ### we use rolling window method to evaluate optimal portfolio
# and window size=2000 > 2 * stocks

# %%
class Returns:
    def __init__(self, mean,cov):
        self.mean = mean
        self.cov = cov
        
    def statistics(self,weights):        
        weights = np.array(weights)
        pret = np.sum(self.mean * weights) # total returns 
        pvol = np.sqrt(np.dot(weights.T, np.dot(self.cov, weights))) # std 
        return np.array([pret, pvol, pret / pvol])

    def min_func_sharpe(self,weights):
        return -self.statistics(weights)[2]
    
    def min_func_variance(self,weights):
        return self.statistics(weights)[1]**2

    def min_func_port(self,weights):
        return self.statistics(weights)[1]

# %%
clean_log_return = log_return.iloc[1:,:]
date_length = len(clean_log_return)
num_stocks = len(clean_log_return.columns)
n_portfolios = 25000
bnds = tuple((0, 1) for x in range(num_stocks))
cons = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
init = num_stocks * [1. / num_stocks,]
window_length = 2000
time_interval = 10
q = num_stocks*1.0/window_length
lambda_plus = (1 + np.sqrt(q))**2

# %%
clean_log_return.loc['2013-01-01':,:]
# Out:
#                CIN.L    CIR.MI     CKN.L    CLE.MI     CLI.L    CRI.PA  \
# date
# 2013-01-01  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2013-01-02  0.000000  0.026701 -0.016807 -0.012442 -0.026145  0.058841
# 2013-01-03  0.000000  0.052518  0.006757  0.000000  0.019673  0.009479
# 2013-01-04  0.013986  0.024693 -0.011003  0.004626  0.006473 -0.003150
# 2013-01-07  0.040822  0.000000  0.021053 -0.025719  0.036736  0.006289
# 2013-01-08 -0.006689  0.019102  0.004988  0.030788 -0.014407  0.009360
# 2013-01-09  0.000000  0.018197 -0.001660  0.017305  0.000000  0.027567
# 2013-01-10  0.000000  0.014646  0.029462 -0.009988 -0.022329  0.032692
# 2013-01-11  0.000000 -0.003236  0.012821 -0.000443  0.010908 -0.032692
# 2013-01-14  0.000000 -0.006504  0.008720 -0.014243 -0.023895  0.023882
# 2013-01-15  0.000000 -0.010935  0.006294  0.015608  0.000000  0.000000
# 2013-01-16  0.000000 -0.005513  0.009368 -0.023051  0.012987 -0.029942
# 2013-01-17  0.000000  0.020247 -0.009368  0.023494 -0.006473  0.047487
# 2013-01-18  0.000000 -0.014185 -0.000785  0.168500  0.016742  0.000000
# 2013-01-21  0.000000  0.006026  0.000785 -0.055380 -0.029157 -0.047487
# 2013-01-22  0.000000  0.001637 -0.011041 -0.032227  0.005900 -0.012233
# 2013-01-23  0.000000 -0.010414  0.001585  0.021190 -0.006557 -0.006173
# 2013-01-24 -0.041102 -0.002206  0.006314  0.003289  0.015018  0.006173
# 2013-01-25  0.000000 -0.006648  0.000000 -0.020712  0.017347  0.003072
# 2013-01-28 -0.007018 -0.027044  0.062520  0.005016 -0.029737  0.021245
# 2013-01-29  0.000000 -0.002287 -0.020157 -0.004593  0.016917  0.000000
# 2013-01-30  0.000000 -0.015576  0.039917 -0.013050  0.006431 -0.018182
# 2013-01-31  0.000000 -0.007001  0.000000  0.000840 -0.020726 -0.018519
# 2013-02-01 -0.014185 -0.004695  0.014389 -0.004241  0.004571  0.015456
# 2013-02-04  0.000000 -0.033496 -0.014389 -0.044328 -0.002609 -0.006154
# 2013-02-05 -0.014389 -0.011009  0.000000  0.008846  0.005861 -0.015552
# 2013-02-06  0.000000 -0.007407  0.014389 -0.025879 -0.004556 -0.025398
# 2013-02-07  0.000000  0.004328  0.014889  0.063904  0.011028 -0.009693
# 2013-02-08  0.000000  0.030977 -0.001408  0.002965  0.000000  0.000000
# 2013-02-11  0.000000 -0.009012  0.014691 -0.017486  0.001289  0.012903
# ...              ...       ...       ...       ...       ...       ...
# 2018-12
# 2013-01-16  0.006874 -0.004250  0.000311
# 2013-01-17  0.011283 -0.000953  0.002639
# 2013-01-18  0.026941  0.015983 -0.001398
# 2013-01-21  0.000618  0.001393  0.002792
# 2013-01-22 -0.005369 -0.004662 -0.004190
# 2013-01-23  0.002688  0.003269 -0.000311
# 2013-01-24  0.007201  0.005574  0.009134
# 2013-01-25 -0.000410 -0.000927  0.007676
# 2013-01-28 -0.007824 -0.002324 -0.003984
# 2013-01-29 -0.004558 -0.016408 -0.002614
# 2013-01-30 -0.000415 -0.022476 -0.014888
# 2013-01-31 -0.005207 -0.047023 -0.035142
# 2013-02-01  0.025360 -0.062216 -0.023580
# 2013-02-04 -0.006536 -0.045235 -0.058689
# 2013-02-05  0.004090 -0.000560  0.029263
# 2013-02-06  0.002242 -0.009075 -0.004962
# 2013-02-07 -0.005718 -0.017242 -0.006192
# 2013-02-08  0.008971  0.009802  0.034764
# 2013-02-11 -0.005495 -0.018540 -0.016131
# ...              ...       ...       ...
# 2018-12-03  0.032945 -0.003110  0.020575
# 2018-12-04  0.004245 -0.030271 -0.024766
# 2018-12-05 -0.016882  0.003663 -0.006862
# 2018-12-06 -0.019470 -0.038672 -0.039172
# 2018-12-07  0.008332 -0.002378 -0.000251
# 2018-12-10 -0.020537 -0.021175 -0.027001
# 2018-12-11  0.014086  0.007752  0.001548
# 2018-12-12  0.004790  0.031824  0.033339
# 2018-12-13  0.018935  0.008380  0.014973
# 2018-12-14 -0.009628  0.004625 -0.002829
# 2018-12-17 -0.018700 -0.013941 -0.008038
# 2018-12-18 -0.005679 -0.015563 -0.009230
# 2018-12-19  0.006727 -0.014361  0.012825
# 2018-12-20 -0.008416 -0.023909 -0.015837
# 2018-12-21  0.004427 -0.014625 -0.012013
# 2018-12-22  0.000000  0.000000  0.000000
# 2018-12-24 -0.025350 -0.025786 -0.009972
# 2018-12-25  0.000000  0.000000  0.000000
# 2018-12-26  0.000000  0.000000  0.000000
# 2018-12-27  0.012436 -0.011793 -0.007610
# 2018-12-28  0.015855  0.032152  0.021264
# 2018-12-31  0.016639  0.008129  0.007073
# 2019-01-01  0.000000  0.000000  0.000000
# 2019-01-02 -0.014963  0.000500  0.001132
# 2019-01-03 -0.028889 -0.003402  0.008013
# 2019-01-04  0.029308  0.045462  0.036728
# 2019-01-07 -0.011790  0.003347  0.005634
# 2019-01-08  0.016175  0.000954  0.008214
# 2019-01-09  0.023274 -0.001432 -0.004277
# 2019-01-10 -0.002650 -0.015400  0.017936
#
# [1582 rows x 412 columns]

# %%
methods = ['normal','clipping']
in_sample_weight = []
ind = clean_log_return.index
for method in methods:
    returns = clean_log_return
    returns_mean = returns.mean()*252
    returns_cov =  compute_cov_metrix(returns,method,threshold=lambda_plus)*252
    Re = Returns(returns_mean,returns_cov)
    opts = sco.minimize(Re.min_func_sharpe,init, method='SLSQP',  bounds=bnds, constraints=cons)
    in_sample_weight.append(opts['x'])

# %%
insample_mean = clean_log_return.loc['2013-01-01':,:].copy()
tmp = insample_mean.copy()
insample_mean['normal'] = np.dot(tmp,in_sample_weight[0])
insample_mean['clipping'] =  np.dot(tmp,in_sample_weight[1])
insample_mean['expect_returns_normal'] = 0.0
insample_mean['expect_returns_clipping']  = 0.0
inde = insample_mean.index
for i in range(len(insample_mean)):
        indexx = inde[i]
        insample_mean.at[indexx,'expect_returns_normal'] = np.exp(insample_mean["normal"][:i+1].sum())-1
        insample_mean.at[indexx,'expect_returns_clipping'] = np.exp(insample_mean['clipping'][:i+1].sum())-1

fig,ax = plt.subplots(figsize=(8,5))
plt.plot(insample_mean.index,insample_mean['expect_returns_normal'],)
plt.plot(insample_mean.index,insample_mean['expect_returns_clipping'])
ax.set_xlabel('date')
ax.set_ylabel('In-sample mean-variance Expect Returns')
ax.legend()
fig.savefig('figure/insample-mean-var-prediction.jpg')

# %%
methods = ['normal','clipping']
in_sample_weight_min = []
ind = clean_log_return.index
for method in methods:
    returns = clean_log_return
    returns_mean = returns.mean()*252
    returns_cov =  compute_cov_metrix(returns,method,threshold=lambda_plus)*252
    Re = Returns(returns_mean,returns_cov)
    opts = sco.minimize(Re.min_func_variance,init, method='SLSQP',  bounds=bnds, constraints=cons)
    in_sample_weight_min.append(opts['x'])

# %%
insample_min = clean_log_return.loc['2013-01-01':,:].copy()
tmp = insample_min.copy()
insample_min['normal'] = np.dot(tmp,in_sample_weight_min[0])
insample_min['clipping'] =  np.dot(tmp,in_sample_weight_min[1])
insample_min['expect_returns_normal'] = 0.0
insample_min['expect_returns_clipping']  = 0.0
inde = insample_min.index
for i in range(len(insample_min)):
        indexx = inde[i]
        insample_min.at[indexx,'expect_returns_normal'] = np.exp(insample_min["normal"][:i+1].sum())-1
        insample_min.at[indexx,'expect_returns_clipping'] = np.exp(insample_min['clipping'][:i+1].sum())-1

fig,ax = plt.subplots(figsize=(8,5))
plt.plot(insample_min.index,insample_min['expect_returns_normal'],)
plt.plot(insample_min.index,insample_min['expect_returns_clipping'])
ax.set_xlabel('date')
ax.set_ylabel('In-sample min-variance Expect Returns')
ax.legend()
fig.savefig('figure/insample-min-var-prediction.jpg')

# %%
methods = ['normal','clipping']
a = []
ind = clean_log_return.index
for method in methods:
    strategy = pd.DataFrame(columns=clean_log_return.columns[:num_stocks])
    for time in range(0,date_length-window_length-time_interval,time_interval):
        print('from '+ str(ind[time])+' to'+ str(ind[time+window_length-1]))
        returns = clean_log_return.iloc[time:time+window_length,:num_stocks]
        date = clean_log_return.index[time+window_length]
        returns_mean = returns.mean()*252
        returns_cov =  compute_cov_metrix(returns,method,threshold=lambda_plus)*252
        Re = Returns(returns_mean,returns_cov)
        #means,stds = np.column_stack([random_portfolio(returns_mean,returns_cov) for _ in range(n_portfolios)])
        opts = sco.minimize(Re.min_func_sharpe,init, method='SLSQP',  bounds=bnds, constraints=cons)
        strategy.loc[date,:] = opts['x']
    strategy.to_csv('min_sharpe_Weight_'+method+'.csv')
    a.append(strategy)

b = []
for method in methods:
    strategy = pd.DataFrame(columns=clean_log_return.columns[:num_stocks])
    for time in range(0,date_length-window_length-time_interval,time_interval):
        print('from '+ str(ind[time])+' to'+ str(ind[time+window_length-1]))
        returns = clean_log_return.iloc[time:time+window_length,:num_stocks]
        date = clean_log_return.index[time+window_length]
        returns_mean = returns.mean()*252
        returns_cov =  compute_cov_metrix(returns,method,threshold=lambda_plus)*252
        Re = Returns(returns_mean,returns_cov)
        #means,stds = np.column_stack([random_portfolio(returns_mean,returns_cov) for _ in range(n_portfolios)])
        opts = sco.minimize(Re.min_func_variance,init, method='SLSQP',  bounds=bnds, constraints=cons)
        strategy.loc[date,:] = opts['x']
    strategy.to_csv('min_variance_Weight_'+method+'.csv')
    b.append(strategy)

# %%
nor_sharp_weight = pd.read_csv('min_sharpe_Weight_normal.csv',index_col=0)
clip_sharp_weight = pd.read_csv('min_sharpe_Weight_clipping.csv',index_col=0)
nor_var_weight = pd.read_csv('min_variance_Weight_normal.csv',index_col=0)
clip_var_weight = pd.read_csv('min_variance_Weight_clipping.csv',index_col=0)

predict_returns = clean_log_return.loc['2007-09-03':,:]
predict_returns.reset_index(inplace=True)
predict_returns.index = (predict_returns.index/10).astype(int)
groups = predict_returns.groupby(predict_returns.index)

# %%
def predict(weight,groups,method_name):
    new_list = []
    for i in range(len(groups)-1):
        group = groups.get_group(i)
        group.set_index('date',inplace=True)
        group[method_name] = np.dot(group,weight.iloc[i,:])
        new_list.append(group)
    df =  pd.concat(new_list)
    tmp = df.copy()
    for i in range(len(df)):
        tmp.iloc[i][method_name] = np.exp(df[method_name][:i+1].sum())-1
    return tmp

# %%
pre_mean_nor = predict(nor_sharp_weight,groups,'mean-var-nor')
pre_mean_clip = predict(clip_sharp_weight,groups,'mean-var-clip')
pre_min_nor = predict(nor_var_weight,groups,'min-var-nor')
pre_min_clip = predict(clip_var_weight,groups,'min-var-clip')

# %%
fig,ax = plt.subplots(figsize=(10,8))
plt.plot(pre_mean_nor.index,pre_mean_nor['mean-var-nor'],)
plt.plot(pre_mean_clip.index,pre_mean_clip['mean-var-clip'])
plt.plot(pre_min_nor.index,pre_min_nor['min-var-nor'],)
plt.plot(pre_min_clip.index,pre_min_clip['min-var-clip'])
ax.set_xlabel('date')
ax.set_ylabel('Out-sample Expect Returns')
ax.legend()
fig.savefig('figure/mean-var-prediction')

# %% [markdown]
# ## here we only set two strategies(actually four), maybe we need to add one used shrinkage or maybe change the window stripe

# %%
plt.figure(figsize=(9, 5)) 
plt.scatter(stds, means, c=means / stds, marker='o') #画散点图
plt.grid(True)
plt.xlabel('expected volatility')
plt.ylabel('expected return')
plt.colorbar(label='Sharpe ratio')

# %% [markdown]
# Next, lets evaluate how many of these random portfolios would perform. Towards this goal we are calculating the mean returns as well as the volatility (here we are using standard deviation). You can also see that there is
# a filter that only allows to plot portfolios with a standard deviation of < 2 for better illustration.

# %%
statistics(opts['x'],returns_mean,returns_cov).round(3)
# Out:
# array([0.121, 0.055, 2.197])
